# %%
from sympy import *


a = (sqrt(E)/((log(7,2)-1)**(3) * (pi+2*E)**(5)) + pi**(S(1)/8))**(S(1)/3)

N(S(a), 40)
# Out:
# 1.048854708968590841171631288846092734435

# %%
var('u z x y')

a = 8*u**2 * x**2 *z - 12*u**2 * x**2 + 8*u**2 * x*y*z - 12*u**2 * x * y + 2*u**2 * y**2 * z - 3*u**2 * y**2 + 16*u*x**2 * z**2 - 24*u*x**2 *z + 16 * u*x*y*z**2 - 24 * u*x*y*z + 4*u*y**2 * z**2 - 6 * u * y**2 * z + 8* x**2 * z**3 - 12 * x**2 * z**2 + 8*x*y*z**3 - 12*x*y*z**2+ 2* y**2 * z**3 - 3*y**2*z**2
factor(a)
# Out:
# (u + z)**2*(2*x + y)**2*(2*z - 3)

# %%
var('x y z u')
expand((x-2*y)**2 * (x+2*y)**2 *(u+z-1))
# Out:
# u*x**4 - 8*u*x**2*y**2 + 16*u*y**4 + x**4*z - x**4 - 8*x**2*y**2*z + 8*x**2*y**2 + 16*y**4*z - 16*y**4

# %%
from sympy import *
var('x')
solveset(36*x**4 + 17*x**3 + 56*x**2 - 303*x - 70, x)
# Out:
# FiniteSet(-2/9, 7/4, -1 - 2*I, -1 + 2*I)

# %%
var('y x')
plot_implicit(-3*x**8 + 3*x**4 - 2*y**8 + 2*y**4, aspect_ratio =(1,1))

# %%
var('t')

plotting.plot_parametric(6*sin(7*t),3*sin(2*t) ,(t, 0, 2*pi), aspect_ratio = (1,1))
